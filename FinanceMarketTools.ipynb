# %% [markdown]
# <a href="https://colab.research.google.com/github/drpietech/sandbox/blob/main/FinanceMarketTools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
data = yf.download(["AAPL"],start='2024-01-01',end='2024-03-21')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count   55.000000   55.000000   55.000000   55.000000   55.000000
# mean   182.857091  184.300000  181.334727  182.957272  182.839804
# std      6.975606    6.802548    6.860985    6.911708    6.827636
# min    169.000000  170.729996  168.490005  169.000000  169.000000
# 25%    179.705002  181.479996  178.315002  180.205002  180.205002
# 50%    183.479996  185.039993  181.669998  184.149994  184.015198
# 75%    187.094994  188.904999  185.834999  187.414993  187.295403
# max    195.419998  196.380005  194.339996  195.179993  194.931259
#
#              Volume
# count  5.500000e+01
# mean   6.121306e+07
# std    1.926375e+07
# min    4.044470e+07
# 25%    4.813565e+07
# 50%    5.546780e+07
# 75%    6.920490e+07
# max    1.366826e+08
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
data.tail(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-14  172.910004  174.309998  172.050003  173.000000  173.000000
# 2024-03-15  171.169998  172.619995  170.289993  172.619995  172.619995
# 2024-03-18  175.570007  177.710007  173.520004  173.720001  173.720001
# 2024-03-19  174.339996  176.610001  173.029999  176.080002  176.080002
# 2024-03-20  175.720001  178.669998  175.089996  178.669998  178.669998
#
#                Volume
# Date
# 2024-03-14   72913500
# 2024-03-15  121664700
# 2024-03-18   75604200
# 2024-03-19   55215200
# 2024-03-20   53423100

# %% [markdown]
# Let's see how Quandl says.
# https://github.com/quandl/quandl-python

# %%
# !pip install quandl

# %%
import quandl
quandl.ApiConfig.api_key = 'tEsTkEy123456789'
quandl.ApiConfig.verify_ssl = False
